# %%
import pandas as pd
all_dfs = pd.read_excel(io="/Users/barta/Documents/Coding/R/K-monitor/data/TEIR.xlsx", sheet_name=None)
year = "2021"

# %%
df = pd.DataFrame()

# %%
for sheet in all_dfs.keys():
    row = pd.DataFrame({"Település": [all_dfs[sheet].columns[0]], all_dfs[sheet].loc[0][0]: all_dfs[sheet][year][0]})
    df = pd.concat([df,row], ignore_index=True)

# %%
df.head(20)
# Out:
#               Település  \
# 0            Aba (1737)
# 1     Abádszalók (1244)
# 2       Abaliget (1254)
# 3       Abasár * (2455)
# 4     Abaújalpár (1566)
# 5       Abaújkér (2671)
# 6        Abaújlak (282)
# 7     Abaújszántó (359)
# 8   Abaújszolnok (2633)
# 9        Abaújvár (227)
# 10          Abda (1188)
# 11        Abod * (1035)
# 12         Abony (2787)
# 13  Ábrahámhegy * (456)
# 14            Ács (442)
# 15          Acsa (1857)
# 16          Acsád (721)
# 17       Acsalag (3338)
# 18     Ácsteszér (1813)
# 19         Adács (2324)
#
#     Szociális támogatásban részesülő nyilvántartott álláskeresők (fő)
# 0                                                 5.0
# 1                                                77.0
# 2                                                 8.0
# 3                                                15.0
# 4                                                 4.0
# 5                                                20.0
# ...
